# %%
import pandas as pd
df = pd.read_csv("HR Data.csv")

df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    Gender                JobRole  JobSatisfaction MaritalStatus  \
# ...

# %%
# df[(df['Age'] > 40) & (df['Department'] == 'Sales') & (df['JobSatisfaction'] == 4)]

# df.T

df.head(1).transpose() #eyni

df.T[0]                 #eyni

df.iloc[0].transpose()  #eyni
# Out:
# Age                               41
# Attrition                        Yes
# BusinessTravel         Travel_Rarely
# DailyRate                       1102
# Department                     Sales
# DistanceFromHome                   1
# Education                          2
# EducationField         Life Sciences
# EmployeeCount                      1
# EmployeeNumber                     1
# Gender                        Female
# JobRole              Sales Executive
# JobSatisfaction                    4
# MaritalStatus                 Single
# MonthlyIncome                   5993
# MonthlyRate                    19479
# Over18                             Y
# OverTime                         Yes
# PerformanceRating                  3
# TotalWorkingYears                  8
# Name: 0, dtype: object

# %%
# df[['EmployeeNumber', 'Age', 'Gender', 'MonthlyIncome']]
df.loc[:, ['EmployeeNumber', 'Age', 'Gender', 'MonthlyIncome']]
# Out:
#       EmployeeNumber  Age  Gender  MonthlyIncome
# 0                  1   41  Female           5993
# 1                  2   49    Male           5130
# 2                  4   37    Male           2090
# 3                  5   33  Female           2909
# 4                  7   27    Male           3468
# ...              ...  ...     ...            ...
# 1465            2061   36    Male           2571
# 1466            2062   39    Male           9991
# 1467            2064   27    Male           6142
# 1468            2065   49    Male           5390
# 1469            2068   34    Male           4404
#
# [1470 rows x 4 columns]

# %%
df.melt()
df.melt().iloc[2000:2100]
# Out:
#        variable value
# 2000  Attrition    No
# 2001  Attrition    No
# 2002  Attrition    No
# 2003  Attrition    No
# 2004  Attrition    No
# ...         ...   ...
# 2095  Attrition    No
# 2096  Attrition    No
# 2097  Attrition    No
# 2098  Attrition    No
# 2099  Attrition    No
#
# [100 rows x 2 columns]

# %%
df.melt(id_vars=["MonthlyIncome", "JobSatisfaction"], var_name="Metric", value_name="Value")

df.transpose()
# Out:
#                               0                       1     \
# Age                             41                      49
# Attrition                      Yes                      No
# BusinessTravel       Travel_Rarely       Travel_Frequently
# DailyRate                     1102                     279
# Department                   Sales  Research & Development
# DistanceFromHome                 1                       8
# Education                        2                       1
# EducationField       Life Sciences           Life Sciences
# EmployeeCount                    1                       1
# EmployeeNumber                   1                       2
# Gender                      Female                    Male
# JobRole            Sales Executive      Research Scientist
# JobSatisfaction                  4                       2
# MaritalStatus               Single                 Married
# MonthlyIncome                 5993                    5130
# ...

# %%
df.groupby(['Department', 'Gender'])['MonthlyIncome'].mean().sort_values()
# Out:
# Department              Gender
# Research & Development  Male      6129.888316
# Human Resources         Male      6371.023256
# Research & Development  Female    6513.691293
# Sales                   Male      6949.645914
#                         Female    6972.126984
# Human Resources         Female    7264.000000
# Name: MonthlyIncome, dtype: float64
