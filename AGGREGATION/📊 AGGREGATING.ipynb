# %%
import pandas as pd
df = pd.read_excel("factory_data.xlsx")
df.head()

# ✅ 1. sum() → Toplama
# 👉 df["Revenue"].sum() → Revenue toplamı
# 👉 df.groupby("Category")["Revenue"].sum() → Kategoriya bazda Revenue toplamı
df.groupby("Month")["Sales"].sum()
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
               "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

df["Month"] = pd.Categorical(df["Month"], categories=month_order, ordered=True)
df = df.sort_values("Month")
df.head()
# Out:
#     Year Month   Category  Production   Sales  Revenue  Expenses
# 0   2023   Jan    Machine       441.0   398.0    23880   17199.0
# 1   2023   Jan      Labor      1060.0  1036.0    42476   36040.0
# 2   2023   Jan  Logistics       575.0   525.0    21000   13800.0
# 38  2024   Jan  Logistics       829.0   819.0    43407   25699.0
# 37  2024   Jan      Labor      1126.0  1095.0    43800   43914.0

# %%
# ✅ 2. mean() → Ortalama
# 👉 df["Revenue"].mean() → Ortalama Revenue
# 👉 df.groupby("Category")["Revenue"].mean() → Kategoriya bazda ortalama
df.groupby("Category")["Sales"].mean().round()
# Out:
# Category
# Labor        726.0
# Logistics    762.0
# Machine      691.0
# Name: Sales, dtype: float64

# %%
# ✅ 3. count() → Sayma
# 👉 df["Category"].count() → Category’de boş olmayan setır sayısı
# 👉 df.groupby("Category")["Revenue"].count() → Kategoriy bazda Revenue sayısı

df.groupby("Month")["Revenue"].count().reset_index(name="Revenue_count")
# Out:
# C:\Users\nicat\AppData\Local\Temp\ipykernel_3624\3222767790.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Month")["Revenue"].count().reset_index(name="Revenue_count")
#    Month  Revenue_count
# 0    Jan              6
# 1    Feb              6
# 2    Mar              6
# 3    Apr              6
# 4    May              6
# 5    Jun              6
# 6    Jul              6
# 7    Aug              6
# 8    Sep              6
# 9    Oct              6
# 10   Nov              6
# 11   Dec              6

# %%
# ✅ 4. min(), max() → Minimum ve maksimum
# 👉 df["Revenue"].min(), df["Revenue"].max() → En kiçik, en boyük Revenue

# ✅ 5. describe() → statistik özeti
# 👉 df.describe() → Butun numeric sütunların count, mean, std, min, 25%, 50%, 75%, max özetini verir

# ✅ 6. agg() → Özel özetleme
# 👉 df.agg({"Revenue": ["sum", "mean"], "Expenses": ["max"]})
df.agg({"Month" : "count", "Sales" :["mean", "std"]}).T.fillna(0).round()
# Out:
#        count   mean    std
# Month   72.0    0.0    0.0
# Sales    0.0  726.0  254.0

# %%
# ✅ 7. groupby() + agg() → Kombo özet
# 👉 df.groupby("Category").agg({"Revenue": "sum", "Expenses": "mean"})

df.groupby("Month").agg({"Revenue" : "mean", "Sales" : ["std","sum"]}).round()


# ✅ 8. pivot_table() → Pivot table özetleme
# 👉 df.pivot_table(values="Revenue", index="Category", aggfunc="sum")

df.pivot_table(index ="Month", columns="Category", values="Revenue", aggfunc=["sum","mean"])
# Out:
# C:\Users\nicat\AppData\Local\Temp\ipykernel_3624\360317713.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("Month").agg({"Revenue" : "mean", "Sales" : ["std","sum"]}).round()
# C:\Users\nicat\AppData\Local\Temp\ipykernel_3624\360317713.py:10: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index ="Month", columns="Category", values="Revenue", aggfunc=["sum","mean"])
# ...
