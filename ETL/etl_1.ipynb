# %%
import pandas as pd
kdf = pd.read_csv("HR Data.csv", sep= ",", usecols=[1,2,3], nrows= 100)
# sep -separator comma, usecols = belirli sutun, nrows= setir sayi

kdf.head()
kdf.tail()
# Out:
#    Attrition BusinessTravel  DailyRate
# 95        No  Travel_Rarely       1217
# 96        No  Travel_Rarely       1353
# 97        No     Non-Travel        120
# 98        No  Travel_Rarely        682
# 99        No     Non-Travel        489

# %%
kdf.columns # sutunlarin isimlerini index list verir

# %%
kdf.shape
# satir ve sutun sayini verir
# Out:
# (1470, 20)

# %%
kdf.describe()
# count, mean, std., min, max, 25%,50%,75% verir
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  JobSatisfaction  MonthlyIncome   MonthlyRate  \
# count     1470.000000      1470.000000    1470.000000   1470.000000
# mean      1024.865306         2.728571    6502.931293  14313.103401
# ...

# %%
jdf = pd.read_json("web_app.json", lines = True)
# eger json list [] icnde deyilse, sadece {} parentezli setirse lines = true elave olunmali
 
jdf
# Out:
#    id  name  age
# 0   1  John   35
# 1   2   San   30
# 2   3  Mary   31

# %%
eldf = pd.read_excel("temiz_hr.xlsx")
eldf.head() # excel dosyalari csv gibi rahat cunku tabular
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education  \
# 0                 1          2
# 1                 8          1
# 2                 2          2
# 3                 3          4
# 4                 2          1
#
#                                       EducationField  EmployeeCount  \
# 0  <bound method StringMethods.title of <pandas.c...              1
# 1  <bound method StringMethods.title of <pandas.c...              1
# 2  <bound method StringMethods.title of <pandas.c...              1
# 3  <bound method StringMethods.title of <pandas.c...              1
# ...

# %%
df.notnull() # bos olmayan
df.isnull()  # bos olan
df.isnull().sum() # bos olan setir sayi (sutunlara gore gruplayir)
# Out:
# Age                  0
# Attrition            0
# BusinessTravel       0
# DailyRate            0
# Department           0
# DistanceFromHome     0
# Education            0
# EducationField       0
# EmployeeCount        0
# EmployeeNumber       0
# Gender               0
# JobRole              0
# JobSatisfaction      0
# MaritalStatus        0
# MonthlyIncome        0
# MonthlyRate          0
# Over18               0
# OverTime             0
# PerformanceRating    0
# TotalWorkingYears    0
# dtype: int64

# %%
fd = pd.read_excel("factory_data.xlsx")
fd.isnull().sum()
fd["Category"].fillna(fd["Category"].mode())
fd["Production"].isnull().sum() # np.int64(2)
fd["Production"].fillna(fd["Production"].mean(), inplace = True) # inplace gercek veriye uygular
fd["Production"].isnull().sum() # np.int64(0)

fd.dropna 
# data frame-deki tum bos deyerli satirlari siler (dini imani yok kompe satiri siler bu kafir))

fd.dropna(axis =1) 
# tek bir bos deyer iceren sutunu komple siler (pire icin yorgan yakan tip)

fd.dropna(axis=1, how="all")  
# Tümü boş olan sütunları siler

fd.dropna(subset = ["Year", "Month"])
# Year ve Month bos olan satirlari siler
# Out:
# C:\Users\nicat\AppData\Local\Temp\ipykernel_7232\3301926016.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fd["Production"].fillna(fd["Production"].mean(), inplace = True) # inplace gercek veriye uygular
#     Year Month   Category  Production   Sales  Revenue  Expenses
# 0   2023   Jan    Machine       441.0   398.0    23880   17199.0
# 1   2023   Jan      Labor      1060.0  1036.0    42476   36040.0
# 2   2023   Jan  Logistics       575.0   525.0    21000   13800.0
# ...

# %%
fd.describe()
# 1. IQR
# IQR = Q3 -Q1
# Q1-1.5*IQR -den kucukse outlier
# Q3+1.5*IQR -den buyukse outlier

# 2. Mean -Median
# Mean ≈ Median → Dağılım simetrik (outlier yok).

# Mean > Median → Sağa çarpık (büyük outlier'lar var).

# Mean < Median → Sola çarpık (küçük outlier'lar var).

outliers = numeric_df[(numeric_df > (numeric_df.mean() + 3 * numeric_df.std())) | 
                      (numeric_df < (numeric_df.mean() - 3 * numeric_df.std()))]

# Outlier'ları göster
print(outliers.dropna(how='all'))  # Tümü NaN olan satırları at
outliers.count()
# Out:
# Empty DataFrame
# Columns: [Year, Production, Sales, Revenue, Expenses]
# Index: []
# Year          0
# Production    0
# Sales         0
# Revenue       0
# Expenses      0
# dtype: int64
